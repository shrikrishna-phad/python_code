# %% [markdown]
# ![DATA%20PROCESSING.jpg](attachment:DATA%20PROCESSING.jpg)

# %% [markdown]
# ![Feature%20Engineering.jpg](attachment:Feature%20Engineering.jpg)
