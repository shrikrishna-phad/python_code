# %% [markdown]
# # Logistic Regression
#
# ***Supervised Machine Learning Algotithm.***
#
# ***Despite having "REGRESSION" in its name, Logistic Regression is a popularly used Supervised "CLASSIFICATION ALGORITHM"***
#
# ![Logistic%20&%20Linear%20Regression%20diffrence2.jpg](attachment:Logistic%20&%20Linear%20Regression%20diffrence2.jpg)

# %% [markdown]
# ![Logistic%20&%20Linear%20Regression%20diffrence1.jpg](attachment:Logistic%20&%20Linear%20Regression%20diffrence1.jpg)

# %% [markdown]
# ![Logistic%20Regression.jpg](attachment:Logistic%20Regression.jpg)
